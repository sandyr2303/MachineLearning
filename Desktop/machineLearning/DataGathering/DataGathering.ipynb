# %% [markdown]
# # Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# # Opening local csv file

# %%
df_file = pd.read_csv('aug_train.csv').head()
df_file.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# # Opening a csv file from an URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
req = requests.get(url)
data = StringIO(req.text)
df_url = pd.read_csv(data)
df_url.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# # Sep Parameter

# %%
pd.read_csv('movie_titles_metadata.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'])
# Out:
#       sno                        name release_year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# #  Index_col parameter

# %%
pd.read_csv('movie_titles_metadata.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'],index_col='sno')
# Out:
#                             name release_year  rating     votes  \
# sno
# m0    10 things i hate about you         1999     6.9   62847.0
# m1    1492: conquest of paradise         1992     6.2   10421.0
# m2                    15 minutes         2001     6.1   25854.0
# m3         2001: a space odyssey         1968     8.4  163227.0
# m4                       48 hrs.         1982     6.9   22289.0
# ...                          ...          ...     ...       ...
# m612                    watchmen         2009     7.8  135229.0
# m613                         xxx         2002     5.6   53505.0
# m614                       x-men         2000     7.4  122149.0
# m615          young frankenstein         1974     8.0   57618.0
# m616                   zulu dawn         1979     6.4    1911.0
#
#                                                  genres
# sno
# m0                                 ['comedy' 'romance']
# m1          ['adventure' 'biography' 'drama' 'history']
# ...

# %%
pd.read_csv('movie_titles_metadata.tsv',sep='\t',
            names=['sno','name','release_year','rating','votes','genres'],index_col='sno',
            usecols=['sno','name','release_year','genres'])
# Out:
#                             name release_year  \
# sno
# m0    10 things i hate about you         1999
# m1    1492: conquest of paradise         1992
# m2                    15 minutes         2001
# m3         2001: a space odyssey         1968
# m4                       48 hrs.         1982
# ...                          ...          ...
# m612                    watchmen         2009
# m613                         xxx         2002
# m614                       x-men         2000
# m615          young frankenstein         1974
# m616                   zulu dawn         1979
#
#                                                  genres
# sno
# m0                                 ['comedy' 'romance']
# m1          ['adventure' 'biography' 'drama' 'history']
# m2                ['action' 'crime' 'drama' 'thriller']
# m3                     ['adventure' 'mystery' 'sci-fi']
# m4       ['action' 'comedy' 'crime' 'drama' 'thriller']
# ...                                                 ...
# ...

# %% [markdown]
# # Squeeze DataFrame to Series

# %%
pd.read_csv('aug_train.csv',usecols=['enrollee_id']).squeeze()
# Out:
# 0         8949
# 1        29725
# 2        11561
# 3        33241
# 4          666
#          ...
# 19153     7386
# 19154    31398
# 19155    24576
# 19156     5756
# 19157    23834
# Name: enrollee_id, Length: 19158, dtype: int64

# %% [markdown]
# # Skiprows/nrows Parameter

# %%
pd.read_csv('movie_titles_metadata.tsv',sep='\t',
            names=['sno','name','release_year','rating','votes','genres'],index_col='sno',
            usecols=['sno','name','release_year','genres'],skiprows=[1,2])
# Out:
#                             name release_year  \
# sno
# m0    10 things i hate about you         1999
# m3         2001: a space odyssey         1968
# m4                       48 hrs.         1982
# m5             the fifth element         1997
# m6                           8mm         1999
# ...                          ...          ...
# m612                    watchmen         2009
# m613                         xxx         2002
# m614                       x-men         2000
# m615          young frankenstein         1974
# m616                   zulu dawn         1979
#
#                                                  genres
# sno
# m0                                 ['comedy' 'romance']
# m3                     ['adventure' 'mystery' 'sci-fi']
# m4       ['action' 'comedy' 'crime' 'drama' 'thriller']
# m5    ['action' 'adventure' 'romance' 'sci-fi' 'thri...
# m6                       ['crime' 'mystery' 'thriller']
# ...                                                 ...
# ...

# %%
pd.read_csv('movie_titles_metadata.tsv',sep='\t',
            names=['sno','name','release_year','rating','votes','genres'],index_col='sno',
            usecols=['sno','name','release_year','genres'],nrows=5)
# Out:
#                            name  release_year  \
# sno
# m0   10 things i hate about you          1999
# m1   1492: conquest of paradise          1992
# m2                   15 minutes          2001
# m3        2001: a space odyssey          1968
# m4                      48 hrs.          1982
#
#                                              genres
# sno
# m0                             ['comedy' 'romance']
# m1      ['adventure' 'biography' 'drama' 'history']
# m2            ['action' 'crime' 'drama' 'thriller']
# m3                 ['adventure' 'mystery' 'sci-fi']
# m4   ['action' 'comedy' 'crime' 'drama' 'thriller']

# %% [markdown]
# # Encoding parameter

# %%
pd.read_csv('zomato.csv',encoding = 'latin-1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# # dtypes parameter

# %%
pd.read_csv('aug_train.csv',dtype={'target':int})
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Handling Dates

# %%
pd.read_csv('IPL Matches 2008-2020.csv',parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# # Convertors

# %%
def rename(city):
    return city[0]

# %%
pd.read_csv('IPL Matches 2008-2020.csv',converters={'city':rename},usecols=['id','city']).head()
# Out:
#        id city
# 0  335982    B
# 1  335983    C
# 2  335984    D
# 3  335985    M
# 4  335986    K

# %% [markdown]
# # na_values parameter

# %%
# to make specific character as NaN, like 
#to replace '-' with NaN values so pandas provides us functions to handle the same
pd.read_csv('aug_train.csv',na_values=['-',])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Loading a huge dataset in chunks

# %%
dfs = pd.read_csv('aug_train.csv',chunksize = 3000)

# %%
for chunk in dfs:
    print(chunk.shape)
# Out:
# (3000, 14)
# (3000, 14)
# (3000, 14)
# (3000, 14)
# (3000, 14)
# (3000, 14)
# (1158, 14)

# %% [markdown]
# # Working with JSON

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ...

# %% [markdown]
# # Working with SQL

# %%
pip install mysql.connector
# Out:
# ...
#   Using cached mysql-connector-2.2.9.tar.gz (11.9 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp39-cp39-macosx_10_9_x86_64.whl size=247957 sha256=cb2497f0896b99382b031e82c8c250cb227a78dbc1dfc3c7485945560b3a6131
#   Stored in directory: /Users/sandeepkumarreddybollapu/Library/Caches/pip/wheels/ed/d2/ef/350d6d5e22478e792288bdc128a34eb4bb062540097713cbab
# Successfully built mysql.connector
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: /Users/sandeepkumarreddybollapu/opt/anaconda3/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
pd.read_sql_query('SELECT * FROM city',conn)
# Out:
# /Users/sandeepkumarreddybollapu/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# ...

# %% [markdown]
# # API

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=<apiKey>&language=en-US&page=1')
# Out:
# <Response [200]>

# %%
df = pd.DataFrame()

# %%
for i in range(1,429):
     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=<apiKey>&language=en-US&page={}'.format(i))
     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
     df = df.append(temp_df,ignore_index=True)
# Out:
# /var/folders/9l/gs_rnxtj0ml43kbz9r72b4f40000gn/T/ipykernel_29080/315127102.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# /var/folders/9l/gs_rnxtj0ml43kbz9r72b4f40000gn/T/ipykernel_29080/315127102.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# /var/folders/9l/gs_rnxtj0ml43kbz9r72b4f40000gn/T/ipykernel_29080/315127102.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
df.to_csv('movies.csv',index=False)

# %%
pd.read_csv('movies.csv')
# Out:
#            id                     title  \
# 0         278  The Shawshank Redemption
# 1         238             The Godfather
# 2     1184918            The Wild Robot
# 3         240     The Godfather Part II
# 4         424          Schindler's List
# ...       ...                       ...
# 8555     9966            The Messengers
# 8556    41517                    Ra.One
# 8557    14289           Fire Down Below
# 8558     9038        The Heartbreak Kid
# 8559   312669             Maggie's Plan
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     After a shipwreck, an intelligent robot called...   2024-09-12
# 3     In the continuing saga of the Corleone crime f...   1974-12-20
# 4     The true story of how businessman Oskar Schind...   1993-12-15
# ...
